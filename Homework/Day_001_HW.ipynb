# %% [markdown]
# # 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 1. 你選的這組資料為何重要
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 這組資料想解決的問題如何評估

# %% [raw]
# 我選擇London Crime Data這組資料：
# https://www.kaggle.com/LondonDataStore/london-crime
#
# 1. 透過這組資料可以清楚理解倫敦街區的犯罪狀況，分析出對該區域較適當的保護措施。也能透過歷史犯罪紀錄資料去預測未來潛在犯罪狀況，進而提早預防實際犯罪的發生。
#
# 2. 資料為opensource, 在GCP的Big Query上面可取得：https://console.cloud.google.com/marketplace/details/greater-london-authority/london-crime?filter=category:public-safety&pli=1
#
# 3. 資料型態會是結構化資料。這組資料包含兩個倫敦從2008年至今的犯罪歷史紀錄，資料包含：兩個地理變數（LSOA and borough）來劃分犯罪區域、主要與次要犯罪類別、每個月的犯罪次數、犯罪時間的年與月。除了每月犯罪次數與犯罪時間的年與月為連續變數外，其他皆為類別變數。
#
# 4. 想利用此組資料去觀察犯罪是否有特定特性，如區域、季節、時間點等
#    4.1 將各區最常發生哪類犯罪類型做分類，加入區域、季節、時間點等變數去觀察是否有顯著影響力
#    4.2 預測哪個地區/哪個時間點/哪個季節最常發生哪種犯罪類型

# %% [markdown]
# # 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [raw]
# 1. 假設服務品質良好以及能夠迅速叫車為客戶優先考量，並找出標準TA與潛在TA的客群
#
# 2. 紀錄每台載客車輛的接客位置、里程數、載客人數、乘客基本資料（性別年齡等），以及乘客對司機的評價分數作為考量
#
# 3. 資料型態會是結構化資料，包括類別與連續變數，理想的話會包含時間點與經緯度
#
# 4.1 利用客戶對司機的評價分數以及算出接單到實際接到客人的時間差當作兩個主要變數，做回歸評估這兩樣變數是否對總體業績成長有影響
# 4.2 利用客戶基本資料去分群，找出客戶的消費模式，針對不同TA給予不同的宣傳方式

# %% [markdown]
# # 作業3：
# 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
# 資料夾結構建立規則提醒：2nd-ML100Days > data資料夾 & homework資料夾 (ipynb檔)
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    mse = sum(((y-y_hat)**2))/len(y)
    return mse

# %%
def mean_absolute_error(y, y_hat):
    mae = MAE = sum(abs(y - y_hat)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 164.118
# The Mean absolute error is 10.452
